# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Pandas tutorial for beginners

# %%
dates=pd.date_range('20240319', periods=50)

# %%
dates
# Out:
# DatetimeIndex(['2024-03-19', '2024-03-20', '2024-03-21', '2024-03-22',
#                '2024-03-23', '2024-03-24', '2024-03-25', '2024-03-26',
#                '2024-03-27', '2024-03-28', '2024-03-29', '2024-03-30',
#                '2024-03-31', '2024-04-01', '2024-04-02', '2024-04-03',
#                '2024-04-04', '2024-04-05', '2024-04-06', '2024-04-07',
#                '2024-04-08', '2024-04-09', '2024-04-10', '2024-04-11',
#                '2024-04-12', '2024-04-13', '2024-04-14', '2024-04-15',
#                '2024-04-16', '2024-04-17', '2024-04-18', '2024-04-19',
#                '2024-04-20', '2024-04-21', '2024-04-22', '2024-04-23',
#                '2024-04-24', '2024-04-25', '2024-04-26', '2024-04-27',
#                '2024-04-28', '2024-04-29', '2024-04-30', '2024-05-01',
#                '2024-05-02', '2024-05-03', '2024-05-04', '2024-05-05',
#                '2024-05-06', '2024-05-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(50,5), index=dates, columns=list('abcde'))

# %%
df
# Out:
#                    a         b         c         d         e
# 2024-03-19  0.893842  0.233457 -0.886294 -0.877573 -2.393105
# 2024-03-20  0.220875 -0.064068 -0.488618 -0.657361  0.306355
# 2024-03-21 -0.522451 -0.891761  0.142324  0.321425 -0.155483
# 2024-03-22  0.259074  0.045717  1.040489 -0.530609  1.404533
# 2024-03-23  2.189705 -0.859362 -0.069598  1.863320  0.088408
# 2024-03-24 -0.291858  0.938352  0.770254 -0.714929  1.023929
# 2024-03-25 -2.689589  1.361608  0.887462 -1.213720 -0.071652
# 2024-03-26 -0.064476  1.110794 -1.810119  0.513746  0.731541
# 2024-03-27 -0.199504  1.235350 -2.055328 -1.015715 -0.975041
# 2024-03-28  1.397090  0.869217 -0.247296  0.492638 -0.172611
# 2024-03-29 -1.515789 -0.193646 -1.465848 -2.030659 -1.373311
# 2024-03-30 -0.555115 -0.977130  1.158830 -2.379536 -0.879385
# 2024-03-31 -0.134699 -2.113263  0.800144 -1.398272 -0.360373
# 2024-04-01  2.111305 -0.712271 -2.060853  0.229065 -0.273385
# ...

# %%
df.describe()
# Out:
#                a          b          c          d          e
# count  50.000000  50.000000  50.000000  50.000000  50.000000
# mean   -0.168187  -0.256877  -0.238485   0.072820  -0.075834
# std     1.267384   0.972117   1.000682   1.154054   1.108206
# min    -2.996087  -2.321492  -2.060853  -2.379536  -2.964747
# 25%    -0.788988  -0.887438  -0.999964  -0.656337  -0.813318
# 50%    -0.108742  -0.330513  -0.290532  -0.084270  -0.113567
# 75%     0.470694   0.706389   0.686596   0.868008   0.636511
# max     2.672817   1.598736   1.525000   3.371391   3.061894

# %%
df.T
# Out:
#    2024-03-19  2024-03-20  2024-03-21  2024-03-22  2024-03-23  2024-03-24  \
# a    0.893842    0.220875   -0.522451    0.259074    2.189705   -0.291858
# b    0.233457   -0.064068   -0.891761    0.045717   -0.859362    0.938352
# c   -0.886294   -0.488618    0.142324    1.040489   -0.069598    0.770254
# d   -0.877573   -0.657361    0.321425   -0.530609    1.863320   -0.714929
# e   -2.393105    0.306355   -0.155483    1.404533    0.088408    1.023929
#
#    2024-03-25  2024-03-26  2024-03-27  2024-03-28  ...  2024-04-28  \
# a   -2.689589   -0.064476   -0.199504    1.397090  ...   -0.578952
# b    1.361608    1.110794    1.235350    0.869217  ...   -0.225964
# c    0.887462   -1.810119   -2.055328   -0.247296  ...   -0.510105
# d   -1.213720    0.513746   -1.015715    0.492638  ...   -0.934256
# e   -0.071652    0.731541   -0.975041   -0.172611  ...    0.421355
#
#    2024-04-29  2024-04-30  2024-05-01  2024-05-02  2024-05-03  2024-05-04  \
# ...

# %%
df.sort_values(by="d")
# Out:
#                    a         b         c         d         e
# 2024-03-30 -0.555115 -0.977130  1.158830 -2.379536 -0.879385
# 2024-03-29 -1.515789 -0.193646 -1.465848 -2.030659 -1.373311
# 2024-04-10 -0.763728 -1.552401 -0.573853 -1.860259 -2.964747
# 2024-05-04  1.264002 -0.632319 -1.204323 -1.424324  3.061894
# 2024-03-31 -0.134699 -2.113263  0.800144 -1.398272 -0.360373
# 2024-03-25 -2.689589  1.361608  0.887462 -1.213720 -0.071652
# 2024-04-03  0.204639 -1.496664 -1.416147 -1.074179 -0.812434
# 2024-03-27 -0.199504  1.235350 -2.055328 -1.015715 -0.975041
# 2024-04-15 -0.797409  0.934672  1.525000 -0.951921 -1.517952
# 2024-04-28 -0.578952 -0.225964 -0.510105 -0.934256  0.421355
# 2024-03-19  0.893842  0.233457 -0.886294 -0.877573 -2.393105
# 2024-03-24 -0.291858  0.938352  0.770254 -0.714929  1.023929
# 2024-03-20  0.220875 -0.064068 -0.488618 -0.657361  0.306355
# 2024-04-12 -0.481761 -0.598987 -0.616132 -0.653265 -1.226434
# ...

# %%
df["a"]
# Out:
# 2024-03-19    0.893842
# 2024-03-20    0.220875
# 2024-03-21   -0.522451
# 2024-03-22    0.259074
# 2024-03-23    2.189705
# 2024-03-24   -0.291858
# 2024-03-25   -2.689589
# 2024-03-26   -0.064476
# 2024-03-27   -0.199504
# 2024-03-28    1.397090
# 2024-03-29   -1.515789
# 2024-03-30   -0.555115
# 2024-03-31   -0.134699
# 2024-04-01    2.111305
# 2024-04-02    0.369589
# 2024-04-03    0.204639
# 2024-04-04   -0.383448
# 2024-04-05    0.879916
# 2024-04-06   -0.850137
# 2024-04-07    2.672817
# 2024-04-08   -2.861001
# 2024-04-09    0.353769
# 2024-04-10   -0.763728
# 2024-04-11   -2.064210
# 2024-04-12   -0.481761
# 2024-04-13   -0.723724
# 2024-04-14   -1.118018
# 2024-04-15   -0.797409
# 2024-04-16   -0.036450
# 2024-04-17   -2.996087
# 2024-04-18   -1.420361
# 2024-04-19    0.047456
# 2024-04-20   -0.388525
# 2024-04-21   -1.330501
# 2024-04-22    1.372859
# 2024-04-23    0.638198
# 2024-04-24    0.274324
# 2024-04-25    0.504396
# 2024-04-26    1.317010
# 2024-04-27   -0.082786
# ...

# %%
import matplotlib.pyplot as plt
ts = df.cumsum()

# %%
plt.figure()
ts.plot()
# Out:
# <AxesSubplot: >
